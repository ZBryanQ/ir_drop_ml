# %%
import os
from utilities.tiling_csv import tile_csv

# %%
for filename in os.listdir("/home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files"):
    full_file = os.path.join("/home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files", filename)
    with open(full_file) as f:
            first_line = f.readline()
            if len(first_line.split(",")) > 930/2:
                continue
            else:
                print(full_file)
                output_file = os.path.split(full_file)[-1]
                tile_csv(full_file, output_file, 2, 2, out_path = '/home/bqtx/Documents/VLSI/ir_drop_ml/new_via_csvs')
# Out:
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map27_m7_m8.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map23_m1_m4.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map23_m8_m9.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map27_m4_m7.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map27_m1_m4.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map23_m4_m7.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map27_m8_m9.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/via_csv_files/current_map23_m7_m8.csv

# %%
for filename in os.listdir("/home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists"):
    full_file = os.path.join("/home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists", filename)
    with open(full_file) as f:
            first_line = f.readline()
            if len(first_line.split(",")) > 930/2:
                continue
            else:
                print(full_file)
                output_file = os.path.split(full_file)[-1]
                tile_csv(full_file, output_file, 2, 2, out_path = '/home/bqtx/Documents/VLSI/ir_drop_ml/new_via_csvs')
# Out:
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/14_netlist_m8_m9.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/14_netlist_m7_m8.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/13_netlist_m8_m9.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/13_netlist_m7_m8.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/14_netlist_m4_m7.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/14_netlist_m1_m4.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/13_netlist_m4_m7.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_netlists/13_netlist_m1_m4.csv

# %%
for filename in os.listdir("/home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs"):
    full_file = os.path.join("/home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs", filename)
    with open(full_file) as f:
            first_line = f.readline()
            if len(first_line.split(",")) > 930/2:
                continue
            else:
                print(full_file)
                output_file = os.path.split(full_file)[-1]
                tile_csv(full_file, output_file, 2, 2, out_path = '/home/bqtx/Documents/VLSI/ir_drop_ml/new_via_csvs')
# Out:
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs/14_eff_dist_map.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs/14_current_map.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs/14_pdn_density.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs/13_eff_dist_map.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs/13_pdn_density.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_inputs/13_current_map.csv

# %%
for filename in os.listdir("/home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_ir_drop"):
    full_file = os.path.join("/home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_ir_drop", filename)
    with open(full_file) as f:
            first_line = f.readline()
            if len(first_line.split(",")) > 930/2:
                continue
            else:
                print(full_file)
                output_file = os.path.split(full_file)[-1]
                tile_csv(full_file, output_file, 2, 2, out_path = '/home/bqtx/Documents/VLSI/ir_drop_ml/new_via_csvs')
# Out:
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_ir_drop/13_ir_drop_map.csv
# /home/bqtx/Documents/VLSI/ir_drop_ml/EvaluationData/evaluation_ir_drop/14_ir_drop_map.csv

# %%
for filename in os.listdir("/home/bqtx/Documents/VLSI/ir_drop_ml/training_data/all_csvs/inp"):
    full_file = os.path.join("/home/bqtx/Documents/VLSI/ir_drop_ml/training_data/all_csvs/inp", filename)
    with open(full_file) as f:
            first_line = f.readline()
            if len(first_line.split(",")) > 930/2:
                continue
            else:
                print(full_file)
                output_file = os.path.split(full_file)[-1]
                tile_csv(full_file, output_file, 2, 2, out_path = '/home/bqtx/Documents/VLSI/ir_drop_ml/new_via_csvs')
